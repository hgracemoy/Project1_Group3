# %%
#dependencies
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import pandas as pd
import numpy as np
import requests
import time
import pprint
import csv

# %%
rain = "data/precipitation_new.csv"

rain_df = pd.read_csv(rain)
rain_df
# Out:
#      state  Unnamed: 1  year month  precipitation
# 0       AC   1/31/1998  1998   Jan          335.5
# 1       AC   2/28/1998  1998   Feb          299.4
# 2       AC   3/31/1998  1998   Mar          396.7
# 3       AC   4/30/1998  1998   Apr          102.7
# 4       AC   5/31/1998  1998   May           19.0
# ...    ...         ...   ...   ...            ...
# 5809    TO   7/31/2017  2017   Jul            0.0
# 5810    TO   8/31/2017  2017   Aug            0.0
# 5811    TO   9/30/2017  2017   Sep            0.0
# 5812    TO  10/31/2017  2017   Oct           21.6
# 5813    TO  11/30/2017  2017   Nov          197.1
#
# [5814 rows x 5 columns]

# %%
yeargroup_df = rain_df.groupby(["year"])
year_sum = yeargroup_df.sum()["precipitation"]
year_sum_df = pd.DataFrame(year_sum)

year_sum_response = year_sum_df.reset_index()
year_sum_response
# Out:
#     year  precipitation
# 0   1998        39164.8
# 1   1999        41545.0
# 2   2000        46756.6
# 3   2001        34510.5
# 4   2002        42450.8
# 5   2003        41609.6
# 6   2004        47358.5
# 7   2005        45354.4
# 8   2006        45854.7
# 9   2007        40209.7
# 10  2008        46766.2
# 11  2009        50960.7
# 12  2010        43636.6
# 13  2011        51699.8
# 14  2012        40002.9
# 15  2013        46226.1
# 16  2014        42386.3
# 17  2015        39944.7
# 18  2016        38136.4
# 19  2017        38885.2

# %%
precipitation = [39164.8, 41545.0, 46756.6, 34510.5, 42450.8, 41609.6, 47358.5, 45354.4, 45854.7, 40209.7, 46766.2, 50960.7, 43636.6, 51699.8, 40002.9, 46226.1, 42386.3, 39944.7, 38136.4, 38885.2]
x_axis = np.arange(len(precipitation))

# %%
plt.bar(x_axis, precipitation, color='b', alpha=0.6, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 20 artists>

# %%
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ['1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x121ada510>,
#   <matplotlib.axis.XTick at 0x11034a250>,
#   <matplotlib.axis.XTick at 0x11037d490>,
#   <matplotlib.axis.XTick at 0x120afb210>,
#   <matplotlib.axis.XTick at 0x1103e54d0>,
#   <matplotlib.axis.XTick at 0x1103e5a50>,
#   <matplotlib.axis.XTick at 0x1103e5250>,
#   <matplotlib.axis.XTick at 0x1103ec5d0>,
#   <matplotlib.axis.XTick at 0x1103ecb50>,
#   <matplotlib.axis.XTick at 0x1103ec050>,
#   <matplotlib.axis.XTick at 0x1103f3650>,
#   <matplotlib.axis.XTick at 0x122051e50>,
#   <matplotlib.axis.XTick at 0x122505b50>,
#   <matplotlib.axis.XTick at 0x1237fe510>,
#   <matplotlib.axis.XTick at 0x1237fea90>,
#   <matplotlib.axis.XTick at 0x1237fe8d0>,
#   <matplotlib.axis.XTick at 0x1224eca50>,
#   <matplotlib.axis.XTick at 0x122505590>,
#   <matplotlib.axis.XTick at 0x122505450>,
#   <matplotlib.axis.XTick at 0x122513190>],
#  <a list of 20 Text xticklabel objects>)

# %%
plt.title("Annual Precipitation in Brazil")
plt.xlabel("Year")
plt.ylabel("Precipitation(amount?)")
# Out:
# Text(40.69444444444443, 0.5, 'Precipitation(amount?)')

# %%
state = rain_df.groupby(["state", "year"])
state_groupby = state.sum()["precipitation"]

state_df = pd.DataFrame(state_groupby)

state_response = state_df.reset_index()
state_response
# Out:
#     state  year  precipitation
# 0      AC  1998         2296.1
# 1      AC  1999         2182.2
# 2      AC  2000         1703.5
# 3      AC  2001         1926.9
# 4      AC  2002         1909.9
# ..    ...   ...            ...
# 490    TO  2013         1849.3
# 491    TO  2014         1843.9
# 492    TO  2015         1393.7
# 493    TO  2016         1270.5
# 494    TO  2017         1320.7
#
# [495 rows x 3 columns]

# %%
state_respon.plot(kind="line", x="year", y="precipitation", grid=True, figsize=(20,10),
              title="Horsepower Vs. MPG")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60f67215b977> in <module>
# ----> 1 car_data.plot(kind="line", x="year", y="precipitation", grid=True, figsize=(20,10),
#       2               title="Horsepower Vs. MPG")
#       3 plt.show()
#
# NameError: name 'car_data' is not defined
