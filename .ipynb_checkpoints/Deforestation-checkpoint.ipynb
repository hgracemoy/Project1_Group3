# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
import csv
import random
import seaborn as sns

# %%
# We had to clean the .csv file
# Change the demiliter form ";" to ","
# Change the decimal separator from "," to "."
# Use the abreviation for the States.

defo = "data_joao/deforestation_state_year_clean.csv"
defo_df = pd.read_csv(defo)
defo_df
# Out:
#      year  square km state
# 0    2017       31.0    TO
# 1    2017      132.0    RR
# 2    2017     1243.0    RO
# 3    2017     2433.0    PA
# 4    2017     1561.0    MT
# ..    ...        ...   ...
# 175  1998     6466.0    MT
# 176  1998     1012.0    MA
# 177  1998       30.0    AP
# 178  1998      670.0    AM
# 179  1998     5829.0    PA
#
# [180 rows x 3 columns]

# %%
yeargroup_df = defo_df.groupby(["year"])
year_sum = yeargroup_df.sum()["square km"]
year_sum_df = pd.DataFrame(year_sum)

year_sum_response = year_sum_df.reset_index()
year_sum_response.head()
# Out:
#    year  square km
# 0  1998    17383.0
# 1  1999    17259.0
# 2  2000    18226.0
# 3  2001    18165.0
# 4  2002    21650.0

# %%
x_axis = list(year_sum_response.year)
tick_locations = [value for value in x_axis]

# %%
fig, ax = plt.subplots(figsize=(20, 10))


for index, row in year_sum_response.iterrows():
    
    if year_sum_response["year"][index] < 2004:
        ax.bar(year_sum_response["year"][index], year_sum_response["square km"][index],  color='b', alpha=0.85, align="center")
    else:
        ax.bar(year_sum_response["year"][index], year_sum_response["square km"][index],  color='g', alpha=0.55, align="center")

ax.set_title("Annual Deforestation in Legal Amazon", fontweight = "bold", fontsize = 15)
plt.xticks(tick_locations, x_axis, rotation=90)
ax.set_xlabel("Year")
ax.set_ylabel("Area (km²)")
#plt.style.use('ggplot')
plt.tight_layout()
ax.grid()
#save figure
plt.savefig("output_data/defor_year.png", dpi=fig.dpi)
plt.show()

# %%
stategroup = defo_df.groupby(["state", "year"])
state_sum = stategroup.sum()["square km"]
state_sum_df = pd.DataFrame(state_sum)

state_sum_response = state_sum_df.reset_index()
state_sum_response
# Out:
#     state  year  square km
# 0      AC  1998      536.0
# 1      AC  1999      441.0
# 2      AC  2000      547.0
# 3      AC  2001      419.0
# 4      AC  2002      883.0
# ..    ...   ...        ...
# 175    TO  2013       74.0
# 176    TO  2014       50.0
# 177    TO  2015       57.0
# 178    TO  2016       58.0
# 179    TO  2017       31.0
#
# [180 rows x 3 columns]

# %%
states = np.unique(state_sum_response["state"])

# %%
#create line graph for states and yearly deforestation

fig, ax = plt.subplots(figsize=(15, 10), )

ax = sns.lineplot(x = 'year', y = "square km", data = state_sum_response, hue = 'state', lw = 3, 
                  err_style = None,)

tick_locations = [value for value in x_axis]
handles = states
plt.xticks(tick_locations, x_axis, rotation=90)
ax.set_xlabel("Year")
ax.set_ylabel("Area (km²)")
ax.set_title('Deforestation by State by Year', fontweight = "bold", fontsize = 15)
ax.legend(handles, loc="best", prop={'size': 12})
plt.tight_layout()
ax.grid()
plt.savefig("output_data/def_state_year.png", dpi=fig.dpi)
plt.show()

ax.xaxis.set_major_locator(plt.MaxNLocator(19))
ax.set_xlim(1998, 2017)

ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.legend(loc='best', bbox_to_anchor=(1, 1), fontsize=8)

# %%
Xstategroup = defo_df.groupby(["state"])
Xstate_sum = Xstategroup.mean()["square km"]
Xstate_sum_df = pd.DataFrame(Xstate_sum)

# %%
Xstate_sum
# Out:
# state
# AC     424.70
# AM     751.90
# AP      32.30
# MA     709.65
# MT    4284.40
# PA    4683.75
# RO    1797.55
# RR     232.15
# TO     139.40
# Name: square km, dtype: float64

# %%
test = ["AC", "PA"]

# %%
df_ac = defo_df[defo_df['state'].str.contains("AC")|\
               defo_df['state'].str.contains("PA")]

# %%
state_sum_response.to_csv("data_joao/deforestation_merge.csv",index=False)
